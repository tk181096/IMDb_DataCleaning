# %% [markdown]
# Theory and Practice of Data Cleaning: Final Project Code

# %%
import pandas as pd
import numpy as np

# %%
#Read Dataset crew
crew = pd.read_csv("title_crew.tsv", sep='\t')
crew.head(3)
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N

# %%
crew = crew[['tconst', 'directors']]
crew.head(3)
# Out:
#       tconst  directors
# 0  tt0000001  nm0005690
# 1  tt0000002  nm0721526
# 2  tt0000003  nm0721526

# %%
#Read Dataset basics
basics = pd.read_csv("basics.tsv", sep='\t')
basics.head(3)
# Out:
# /Users/megs/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance

# %%
#Read Dataset akas
akas = pd.read_csv("akas.tsv", sep='\t')
akas.head(3)
# Out:
# /Users/megs/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU       \N
# 1  tt0000001         2                 Καρμενσίτα     GR       \N
# 2  tt0000001         3                 Карменсита     RU       \N
#
#          types attributes isOriginalTitle
# 0  imdbDisplay         \N               0
# 1           \N         \N               0
# 2           \N         \N               0

# %%
akas.dtypes
# Out:
# titleId            object
# ordering            int64
# title              object
# region             object
# language           object
# types              object
# attributes         object
# isOriginalTitle    object
# dtype: object

# %% [markdown]
# convert object datatype for isOriginal to integer type

# %%
#movies_dataframe_akas["isOriginalTitle"]= movies_dataframe_akas.isOriginalTitle.astype(int)

# %% [markdown]
# Select only English Titles (using isOriginalTitle)

# %%
akas=akas.loc[akas['isOriginalTitle'] == '1']
akas.head(10)
# Out:
#          titleId  ordering                             title region language  \
# 65538  tt0020504         1  The Time, the Place and the Girl     \N       \N
# 65542  tt0020506         2                       The Tip Off     \N       \N
# 65554  tt0020508         8                   Tokai kokyogaku     \N       \N
# 65556  tt0020509        10                       Tokkan kozô     \N       \N
# 65575  tt0020510         6                 Tôkyô kôshinkyoku     \N       \N
# 65579  tt0020511         3                 Tonight at Twelve     \N       \N
# 65582  tt0020512         1        Trail of the Horse Thieves     \N       \N
# 65593  tt0020513         9                 Trent's Last Case     \N       \N
# 65596  tt0020514        12                    The Trespasser     \N       \N
# 65610  tt0020515         2                    Trial Marriage     \N       \N
#
#           types attributes isOriginalTitle
# 65538  original         \N               1
# ...

# %% [markdown]
# Check for the duplicates in akas dataframe

# %%
#boolean = any(akas.duplicated(subset=['tconst']))
#print(boolean, end='\n\n')

# %%
#Read Dataset episode
episode = pd.read_csv("episode.tsv", sep='\t')
episode.head(3)
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0041951    tt0041038            1             9
# 1  tt0042816    tt0989125            1            17
# 2  tt0042889    tt0989125           \N            \N

# %%
#Read Dataset ratings
ratings = pd.read_csv("ratings.tsv", sep='\t')
ratings.head(3)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1552
# 1  tt0000002            6.1       186
# 2  tt0000003            6.5      1211

# %%
#Read Dataset principals
principals = pd.read_csv("principals.tsv", sep='\t')
principals.head(3)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
#
#     characters
# 0  ["Herself"]
# 1           \N
# 2           \N

# %%
principals.dtypes
# Out:
# tconst        object
# ordering       int64
# nconst        object
# category      object
# job           object
# characters    object
# dtype: object

# %%
#Read Dataset name_basics
name_basics = pd.read_csv("name_basics.tsv", sep='\t')
name_basics.head(3)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0117057,tt0038355,tt0037382,tt0071877
# 2     actress,soundtrack,producer  tt0054452,tt0059956,tt0049189,tt0057345

# %%
name_basics.dtypes
# Out:
# nconst               object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# dtype: object

# %% [markdown]
# Concatenate dataframes based on nconst: principals + name_basics

# %%
master_table1 = pd.merge(principals,name_basics, on=['nconst'])
print(master_table1)
# Out:
#              tconst  ordering      nconst         category            job  \
# 0         tt0000001         1   nm1588970             self             \N
# 1         tt7513040         2   nm1588970  archive_footage             \N
# 2         tt0000001         2   nm0005690         director             \N
# 3         tt0000005         3   nm0005690         director             \N
# 4         tt0000006         1   nm0005690         director             \N
# ...             ...       ...         ...              ...            ...
# 36633136  tt9916856         3  nm10538646            actor             \N
# 36633137  tt9916856         4  nm10538647          actress             \N
# 36633138  tt9916856         5  nm10538645         director             \N
# 36633139  tt9916856         6   nm6951431           writer  screenplay by
# 36633140  tt9916856         7  nm10538653         composer             \N
#
#            characters           primaryName birthYear deathYear  \
# ...

# %%
master_table1 = pd.DataFrame(data=master_table1)
master_table1.head(10)
# Out:
#       tconst  ordering     nconst         category job   characters  \
# 0  tt0000001         1  nm1588970             self  \N  ["Herself"]
# 1  tt7513040         2  nm1588970  archive_footage  \N  ["Herself"]
# 2  tt0000001         2  nm0005690         director  \N           \N
# 3  tt0000005         3  nm0005690         director  \N           \N
# 4  tt0000006         1  nm0005690         director  \N           \N
# 5  tt0000007         3  nm0005690         director  \N           \N
# 6  tt0000008         2  nm0005690         director  \N           \N
# 7  tt0000036         2  nm0005690         director  \N           \N
# 8  tt0000060         1  nm0005690         director  \N           \N
# 9  tt0000076         2  nm0005690         director  \N           \N
#
#             primaryName birthYear deathYear  \
# 0            Carmencita      1868      1910
# 1            Carmencita      1868      1910
# 2  William K.L. Dickson      1860      1935
# ...

# %% [markdown]
# merge basics dataframe with master_table1 on tconst

# %%
master_table2 = pd.merge(master_table1,basics,on=['tconst'])
#print(master_table2)
master_table2 = pd.DataFrame(data=master_table2)
master_table2.head(10)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt7513040         2  nm1588970  archive_footage                       \N
# 4  tt7513040         7  nm0249379  archive_footage                       \N
# 5  tt7513040         3  nm0000122  archive_footage                       \N
# 6  tt7513040         6  nm0249325             self                       \N
# 7  tt7513040         8  nm0252475             self                       \N
# 8  tt7513040         5  nm0804565         director                       \N
# 9  tt7513040         4  nm0248639             self                       \N
#
#                               characters           primaryName birthYear  \
# ...

# %% [markdown]
# merge crew dataframe with master_table2 on tconst

# %%
master_table3 = pd.merge(master_table2,crew,on=['tconst'])
#print(master_table3)
master_table3 = pd.DataFrame(data=master_table3)
master_table3.head(10)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt7513040         2  nm1588970  archive_footage                       \N
# 4  tt7513040         7  nm0249379  archive_footage                       \N
# 5  tt7513040         3  nm0000122  archive_footage                       \N
# 6  tt7513040         6  nm0249325             self                       \N
# 7  tt7513040         8  nm0252475             self                       \N
# 8  tt7513040         5  nm0804565         director                       \N
# 9  tt7513040         4  nm0248639             self                       \N
#
#                               characters           primaryName birthYear  \
# ...

# %%
master_table3.dtypes
# Out:
# tconst               object
# ordering              int64
# nconst               object
# category             object
# job                  object
# characters           object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# titleType            object
# primaryTitle         object
# originalTitle        object
# isAdult               int64
# startYear            object
# endYear              object
# runtimeMinutes       object
# genres               object
# directors            object
# dtype: object

# %% [markdown]
# merge episode dataframe with master_table3 on tconst

# %%
master_table4 = pd.merge(master_table3,episode,on=['tconst'])
master_table4 = pd.DataFrame(data=master_table4)
master_table4.head(10)
# Out:
#       tconst  ordering     nconst         category job          characters  \
# 0  tt0401146         1  nm0249379  archive_footage  \N         ["Himself"]
# 1  tt0401146         2  nm0673957             self  \N  ["Himself - Host"]
# 2  tt0748486         4  nm0249379  archive_footage  \N         ["Himself"]
# 3  tt0748486         1  nm0001016             self  \N  ["Himself - Host"]
# 4  tt0748486         6  nm1597971         composer  \N                  \N
# 5  tt0748486         8  nm2254436             self  \N         ["Himself"]
# 6  tt0748486        10  nm2369171             self  \N         ["Himself"]
# 7  tt0748486         7  nm2219344         composer  \N                  \N
# 8  tt0748486         9  nm2251841             self  \N         ["Himself"]
# 9  tt0748486         5  nm1600320         director  \N                  \N
#
#         primaryName birthYear deathYear  \
# 0  Thomas A. Edison      1847      1931
# 1      Jack Perkins      1933      2019
# ...

# %%
master_table4.dtypes
# Out:
# tconst               object
# ordering              int64
# nconst               object
# category             object
# job                  object
# characters           object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# titleType            object
# primaryTitle         object
# originalTitle        object
# isAdult               int64
# startYear            object
# endYear              object
# runtimeMinutes       object
# genres               object
# directors            object
# parentTconst         object
# seasonNumber         object
# episodeNumber        object
# dtype: object

# %% [markdown]
# merge ratings dataframe with master_table4 on nconst

# %%
master_table5 = pd.merge(master_table4,ratings,on=['tconst'])
master_table5 = pd.DataFrame(data=master_table5)
master_table5.head(10)
# Out:
#       tconst  ordering     nconst         category job          characters  \
# 0  tt0401146         1  nm0249379  archive_footage  \N         ["Himself"]
# 1  tt0401146         2  nm0673957             self  \N  ["Himself - Host"]
# 2  tt0748486         4  nm0249379  archive_footage  \N         ["Himself"]
# 3  tt0748486         1  nm0001016             self  \N  ["Himself - Host"]
# 4  tt0748486         6  nm1597971         composer  \N                  \N
# 5  tt0748486         8  nm2254436             self  \N         ["Himself"]
# 6  tt0748486        10  nm2369171             self  \N         ["Himself"]
# 7  tt0748486         7  nm2219344         composer  \N                  \N
# 8  tt0748486         9  nm2251841             self  \N         ["Himself"]
# 9  tt0748486         5  nm1600320         director  \N                  \N
#
#         primaryName birthYear deathYear  \
# 0  Thomas A. Edison      1847      1931
# 1      Jack Perkins      1933      2019
# ...

# %%
master_table5.dtypes
# Out:
# tconst                object
# ordering               int64
# nconst                object
# category              object
# job                   object
# characters            object
# primaryName           object
# birthYear             object
# deathYear             object
# primaryProfession     object
# knownForTitles        object
# titleType             object
# primaryTitle          object
# originalTitle         object
# isAdult                int64
# startYear             object
# endYear               object
# runtimeMinutes        object
# genres                object
# directors             object
# parentTconst          object
# seasonNumber          object
# episodeNumber         object
# averageRating        float64
# numVotes               int64
# dtype: object

# %% [markdown]
# Merge Akas and mastertable5 on 'titleId(it's basically a tconst)'

# %%
#First Rename the 'tconst' to 'TitleId' as both the columns are same and we need to get a consistency for the column name to apply further conditions.
master_table5 = master_table5.rename(columns={'tconst': 'titleId'})
master_table5.head(2)
# Out:
#      titleId  ordering     nconst         category job          characters  \
# 0  tt0401146         1  nm0249379  archive_footage  \N         ["Himself"]
# 1  tt0401146         2  nm0673957             self  \N  ["Himself - Host"]
#
#         primaryName birthYear deathYear  primaryProfession  ... startYear  \
# 0  Thomas A. Edison      1847      1931  producer,director  ...      1996
# 1      Jack Perkins      1933      2019                NaN  ...      1996
#
#   endYear runtimeMinutes                 genres  directors parentTconst  \
# 0      \N             \N  Biography,Documentary         \N    tt0092322
# 1      \N             \N  Biography,Documentary         \N    tt0092322
#
#   seasonNumber episodeNumber averageRating numVotes
# 0           \N            \N           7.6       52
# 1           \N            \N           7.6       52
#
# [2 rows x 25 columns]

# %%
final_dataframe = pd.merge(akas,master_table5,on=['titleId'])
final_dataframe = pd.DataFrame(data=final_dataframe)
final_dataframe.head(10)
# Out:
#      titleId  ordering_x      title region language     types attributes  \
# 0  tt0045960           1  King Lear     \N       \N  original         \N
# 1  tt0045960           1  King Lear     \N       \N  original         \N
# 2  tt0045960           1  King Lear     \N       \N  original         \N
# 3  tt0045960           1  King Lear     \N       \N  original         \N
# 4  tt0045960           1  King Lear     \N       \N  original         \N
# 5  tt0045960           1  King Lear     \N       \N  original         \N
# 6  tt0045960           1  King Lear     \N       \N  original         \N
# 7  tt0045960           1  King Lear     \N       \N  original         \N
# 8  tt0045960           1  King Lear     \N       \N  original         \N
# 9  tt0045960           1  King Lear     \N       \N  original         \N
#
#   isOriginalTitle  ordering_y     nconst  ... startYear endYear  \
# 0               1           7  nm0000636  ...      1953      \N
# ...

# %%
final_dataframe.dtypes
# Out:
# titleId               object
# ordering_x             int64
# title                 object
# region                object
# language              object
# types                 object
# attributes            object
# isOriginalTitle       object
# ordering_y             int64
# nconst                object
# category              object
# job                   object
# characters            object
# primaryName           object
# birthYear             object
# deathYear             object
# primaryProfession     object
# knownForTitles        object
# titleType             object
# primaryTitle          object
# originalTitle         object
# isAdult                int64
# startYear             object
# endYear               object
# runtimeMinutes        object
# genres                object
# directors             object
# parentTconst          object
# seasonNumber          object
# episodeNumber         object
# averageRating        float64
# numVotes               int64
# ...

# %% [markdown]
# Observations:
# As we can see that 'title', 'primaryTitle' and 'originalTitle' are basically the same it's just that certain names in 'title' are non-english. Since we are focusing mostly on the English Names(Except for few exceptions where there is no translation involved), we will consider 'primaryTitle' hereafter. We will also remove 'isOriginalTitle' column since all the records considered are for original titles only.

# %%
#quickcheck
df = final_dataframe[['primaryTitle','originalTitle','title','isOriginalTitle']]
df.head(50)
# Out:
#                   primaryTitle               originalTitle  \
# 0                    King Lear                   King Lear
# 1                    King Lear                   King Lear
# 2                    King Lear                   King Lear
# 3                    King Lear                   King Lear
# 4                    King Lear                   King Lear
# 5                    King Lear                   King Lear
# 6                    King Lear                   King Lear
# 7                    King Lear                   King Lear
# 8                    King Lear                   King Lear
# 9                    King Lear                   King Lear
# 10           A Christmas Carol           A Christmas Carol
# 11           A Christmas Carol           A Christmas Carol
# 12           A Christmas Carol           A Christmas Carol
# 13           A Christmas Carol           A Christmas Carol
# 14           A Christmas Carol           A Christmas Carol
# ...

# %% [markdown]
# Drop the above mentioned columns: title, OriginalTitle, isOriginalTitle

# %%
list_to_drop = ['originalTitle','title','isOriginalTitle']

# %%
final_dataframe=final_dataframe.drop(list_to_drop, axis=1)
final_dataframe.head(15)
# Out:
#       titleId  ordering_x region language     types attributes  ordering_y  \
# 0   tt0045960           1     \N       \N  original         \N           7
# 1   tt0045960           1     \N       \N  original         \N           4
# 2   tt0045960           1     \N       \N  original         \N           1
# 3   tt0045960           1     \N       \N  original         \N           9
# 4   tt0045960           1     \N       \N  original         \N           2
# 5   tt0045960           1     \N       \N  original         \N           3
# 6   tt0045960           1     \N       \N  original         \N           6
# 7   tt0045960           1     \N       \N  original         \N          10
# 8   tt0045960           1     \N       \N  original         \N           5
# 9   tt0045960           1     \N       \N  original         \N           8
# 10  tt0046855           2     \N       \N  original         \N           6
# ...

# %% [markdown]
# Consider desired columns

# %%
final_dataframe = final_dataframe[['titleId','nconst', 'region','language','attributes','category','job','characters','primaryName','birthYear','deathYear','primaryProfession','knownForTitles','titleType','primaryTitle','isAdult','startYear','endYear','runtimeMinutes','genres','directors','parentTconst','seasonNumber','episodeNumber','averageRating','numVotes']]
final_dataframe.head(3)
# Out:
#      titleId     nconst region language attributes category   job  \
# 0  tt0045960  nm0000636     \N       \N         \N   writer  play
# 1  tt0045960  nm0281955     \N       \N         \N    actor    \N
# 2  tt0045960  nm0000080     \N       \N         \N    actor    \N
#
#                    characters          primaryName birthYear  ... startYear  \
# 0                          \N  William Shakespeare      1564  ...      1953
# 1  ["Earl of Kent (segment)"]    Bramwell Fletcher      1904  ...      1953
# 2     ["King Lear (segment)"]         Orson Welles      1915  ...      1953
#
#   endYear runtimeMinutes               genres  directors  parentTconst  \
# 0      \N             75  Drama,History,Music  nm0567170     tt0044284
# 1      \N             75  Drama,History,Music  nm0567170     tt0044284
# 2      \N             75  Drama,History,Music  nm0567170     tt0044284
#
#   seasonNumber episodeNumber averageRating numVotes
# 0            2             3           7.0      147
# ...

# %%
final_dataframe.dtypes
# Out:
# titleId               object
# nconst                object
# region                object
# language              object
# attributes            object
# category              object
# job                   object
# characters            object
# primaryName           object
# birthYear             object
# deathYear             object
# primaryProfession     object
# knownForTitles        object
# titleType             object
# primaryTitle          object
# isAdult                int64
# startYear             object
# endYear               object
# runtimeMinutes        object
# genres                object
# directors             object
# parentTconst          object
# seasonNumber          object
# episodeNumber         object
# averageRating        float64
# numVotes               int64
# dtype: object

# %%
#final_dataframe.to_csv('imdb_dataset.csv')

# %%
#read csv
df = pd.read_excel("imdb_dataset_concat.xlsx")
df.head()
# Out:
#      titleId     nconst region language attributes  category   job  \
# 0  tt0045960  nm0000636     \N       \N         \N    writer  play
# 1  tt0045960  nm0281955     \N       \N         \N     actor    \N
# 2  tt0045960  nm0000080     \N       \N         \N     actor    \N
# 3  tt0045960  nm0861110     \N       \N         \N  composer    \N
# 4  tt0045960  nm0663678     \N       \N         \N   actress    \N
#
#                    characters          primaryName birthYear  ... startYear  \
# 0                          \N  William Shakespeare      1564  ...      1953
# 1  ["Earl of Kent (segment)"]    Bramwell Fletcher      1904  ...      1953
# 2     ["King Lear (segment)"]         Orson Welles      1915  ...      1953
# 3                          \N       Virgil Thomson      1896  ...      1953
# 4      ["Cordelia (segment)"]        Natasha Parry      1930  ...      1953
#
#   endYear runtimeMinutes               genres  directors  parentTconst  \
# ...

# %%
table = df.groupby(['titleId','primaryTitle','region','language','attributes','startYear','endYear','runtimeMinutes','genres','directors','parentTconst','seasonNumber','episodeNumber','averageRating','numVotes','isAdult'], sort=False)['category','nconst','job','characters','primaryName','birthYear','deathYear','primaryProfession'].agg(lambda x: '||'.join(x.astype(str))).reset_index()
table
# Out:
#         titleId                primaryTitle region language attributes  \
# 0     tt0045960                   King Lear     \N       \N         \N
# 1     tt0046855           A Christmas Carol     \N       \N         \N
# 2     tt0048378  The Miracle on 34th Street     \N       \N         \N
# 3     tt0048462         The Ox-Bow Incident     \N       \N         \N
# 4     tt0057671          The Forgotten Army     \N       \N         \N
# ...         ...                         ...    ...      ...        ...
# 5053  tt7267456    Thank You and Good Night     \N       \N         \N
# 5054  tt7273480              Darkness Falls     \N       \N         \N
# 5055  tt7278312      Rickety Rockin' Rhonda     \N       \N         \N
# 5056  tt7278346              The Wax Museum     \N       \N         \N
# 5057  tt7278522            Tell All: Part 2     \N       \N         \N
#
#      startYear endYear runtimeMinutes                  genres  directors  ...  \
# ...

# %% [markdown]
# Replace \N with meaningful label for proper understanding of the dataset

# %%
table = table.replace(r'\\N','No Information', regex=True)
table
# Out:
#         titleId                primaryTitle          region        language  \
# 0     tt0045960                   King Lear  No Information  No Information
# 1     tt0046855           A Christmas Carol  No Information  No Information
# 2     tt0048378  The Miracle on 34th Street  No Information  No Information
# 3     tt0048462         The Ox-Bow Incident  No Information  No Information
# 4     tt0057671          The Forgotten Army  No Information  No Information
# ...         ...                         ...             ...             ...
# 5053  tt7267456    Thank You and Good Night  No Information  No Information
# 5054  tt7273480              Darkness Falls  No Information  No Information
# 5055  tt7278312      Rickety Rockin' Rhonda  No Information  No Information
# 5056  tt7278346              The Wax Museum  No Information  No Information
# 5057  tt7278522            Tell All: Part 2  No Information  No Information
#
# ...

# %%
#table.to_csv('final_imdb_dataset.csv')

# %% [markdown]
# Trim all the leading and trailing white spaces in the all the columns

# %%
### Define function
def trim_head_tail_space(df_column):
    clean_df_column = df_column.str.strip()
    print("row changes in column " + str(df_column.name) +": " ,sum(df_column!=clean_df_column))
    return clean_df_column


### Run function
table['titleId'] = trim_head_tail_space(table['titleId'])
table['nconst'] = trim_head_tail_space(table['nconst'])
table['region'] = trim_head_tail_space(table['region'])
table['language'] = trim_head_tail_space(table['language'])
table['attributes'] = trim_head_tail_space(table['attributes'])
table['category'] = trim_head_tail_space(table['category'])
table['job'] = trim_head_tail_space(table['job'])
table['characters'] = trim_head_tail_space(table['characters'])
table['primaryName'] = trim_head_tail_space(table['primaryName'])
table['birthYear'] = trim_head_tail_space(table['birthYear'])
table['deathYear'] = trim_head_tail_space(table['deathYear'])
table['primaryProfession'] = trim_head_tail_space(table['primaryProfession'])
table['primaryTitle'] = trim_head_tail_space(table['primaryTitle'])
table['startYear'] = trim_head_tail_space(table['startYear'])
table['endYear'] = trim_head_tail_space(table['endYear'])
table['runtimeMinutes'] = trim_head_tail_space(table['runtimeMinutes'])
table['genres'] = trim_head_tail_space(table['genres'])
table['directors'] = trim_head_tail_space(table['directors'])
table['parentTconst'] = trim_head_tail_space(table['parentTconst'])
table['seasonNumber'] = trim_head_tail_space(table['seasonNumber'])
table['episodeNumber'] = trim_head_tail_space(table['episodeNumber'])
# Out:
# row changes in column titleId:  0
# row changes in column nconst:  0
# row changes in column region:  0
# row changes in column language:  0
# row changes in column attributes:  0
# row changes in column category:  0
# row changes in column job:  0
# row changes in column characters:  0
# row changes in column primaryName:  0
# row changes in column birthYear:  0
# row changes in column deathYear:  0
# row changes in column primaryProfession:  0
# row changes in column primaryTitle:  3
# row changes in column startYear:  5057
# row changes in column endYear:  0
# row changes in column runtimeMinutes:  4204
# row changes in column genres:  0
# row changes in column directors:  0
# row changes in column parentTconst:  0
# row changes in column seasonNumber:  4787
# row changes in column episodeNumber:  4787

# %% [markdown]
#  Collapse consecutive white spaces

# %%
### Define function
def remove_consecutive_spaces(df_column):
    clean_df_column = df_column.replace('\s+', ' ', regex=True)
    print("row changes in column " + str(df_column.name) +": " ,sum(df_column!=clean_df_column))
    return clean_df_column

### Run function
table['titleId'] = remove_consecutive_spaces(table['titleId'])
table['nconst'] = remove_consecutive_spaces(table['nconst'])
table['region'] = remove_consecutive_spaces(table['region'])
table['language'] = remove_consecutive_spaces(table['language'])
table['attributes'] = remove_consecutive_spaces(table['attributes'])
table['category'] = remove_consecutive_spaces(table['category'])
table['job'] = remove_consecutive_spaces(table['job'])
table['characters'] = remove_consecutive_spaces(table['characters'])
table['primaryName'] = remove_consecutive_spaces(table['primaryName'])
table['birthYear'] = remove_consecutive_spaces(table['birthYear'])
table['deathYear'] = remove_consecutive_spaces(table['deathYear'])
table['primaryProfession'] = remove_consecutive_spaces(table['primaryProfession'])
table['primaryTitle'] = remove_consecutive_spaces(table['primaryTitle'])
table['startYear'] = remove_consecutive_spaces(table['startYear'])
table['endYear'] = remove_consecutive_spaces(table['endYear'])
table['runtimeMinutes'] = remove_consecutive_spaces(table['runtimeMinutes'])
table['genres'] = remove_consecutive_spaces(table['genres'])
table['directors'] = remove_consecutive_spaces(table['directors'])
table['parentTconst'] = remove_consecutive_spaces(table['parentTconst'])
table['seasonNumber'] = remove_consecutive_spaces(table['seasonNumber'])
table['episodeNumber'] = remove_consecutive_spaces(table['episodeNumber'])
# Out:
# row changes in column titleId:  0
# row changes in column nconst:  0
# row changes in column region:  0
# row changes in column language:  0
# row changes in column attributes:  0
# row changes in column category:  0
# row changes in column job:  2
# row changes in column characters:  1
# row changes in column primaryName:  4
# row changes in column birthYear:  0
# row changes in column deathYear:  0
# row changes in column primaryProfession:  0
# row changes in column primaryTitle:  22
# row changes in column startYear:  5057
# row changes in column endYear:  0
# row changes in column runtimeMinutes:  4204
# row changes in column genres:  0
# row changes in column directors:  0
# row changes in column parentTconst:  0
# row changes in column seasonNumber:  4787
# row changes in column episodeNumber:  4787

# %% [markdown]
# Check for integrity Constraints on Titleid, startyear, runtime, average rating, season_number

# %%
#Check if titleid Identifier is unique
#startyear should not be zero 0 
#runtimeMinutes should not zero 
#seasonNumber cannot be 0
#averageRating cannot be greater than 10 and smaller than or equal to zero.

# %%
#Check if titleid Identifier is unique
id_series_titleid = table['titleId']
if (len(set(id_series_titleid)) == len(id_series_titleid)):
    print ("Title_ids are unique!")
else:
    print ("there is a duplicate!")
    

#startyear constraint check
id_series_startyear = table['startYear']
if (len(id_series_startyear) !='0'):
    print ("Start year is valid")
else:
    print ("Start year not valid")
    
#runtime constraint check
id_series_runtime = table['runtimeMinutes']
if (len(id_series_runtime) !='0'):
    print ("runtime is valid")
else:
    print ("runtime is not valid")


#averagerating constraint check
id_series_averageRating = table['averageRating']
if (0.0<=len(id_series_averageRating)<= 10.0):
    print ("averageRating is not valid")
else:
    print ("averageRating is valid")
    

##season_number constraint check
id_series_seasonnumber = table['seasonNumber']
if (len(id_series_seasonnumber) !='0'):
    print ("season number is valid")
else:
    print ("season number is not valid")
# Out:
# Title_ids are unique!
# Start year is valid
# runtime is valid
# averageRating is valid
# season number is valid
